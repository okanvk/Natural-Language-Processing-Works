# %%
#pip install transformers
from transformers import Automodell, AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
model = AutoModel.from_pretrained("dbmdz/bert-base-turkish-cased")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-95307512c72d> in <module>
#       1 #pip install transformers
# ----> 2 from transformers import Automodell, AutoTokenizer
#       3
#       4 tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
#       5 model = AutoModel.from_pretrained("dbmdz/bert-base-turkish-cased")
#
# ImportError: cannot import name 'Automodell' from 'transformers' (//anaconda3/envs/nlp/lib/python3.7/site-packages/transformers/__init__.py)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-4ae80da9abf6> in <module>
# ----> 1 import tensorflow as tf
#       2 tf.__version__
#
# ModuleNotFoundError: No module named 'tensorflow'
